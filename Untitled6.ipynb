# %%
import PIL
from PIL import Image
img = PIL.Image.open("type.png")
wid, hgt = img.size
print(str(wid) + "x" + str(hgt))
# Out:
# 352x352

# %%
import cv2
import numpy as np
img = cv2.imread("type.png")
#cv2.imshow('Image',img)
number_of_white_pix = np.sum(img == 255)
number_of_black_pix = np.sum(img == 0)

print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)
# Out:
# Number of white pixels: 81843
# Number of black pixels: 289869

# %%
import cv2

im = cv2.imread('type.png')

print(type(im))
# <class 'numpy.ndarray'>

print(im.shape)
print(type(im.shape))
# Out:
# <class 'numpy.ndarray'>
# (352, 352, 3)
# <class 'tuple'>

# %%
#phonetics
str1 = input()
str2=["u","y","e","i"]
for str2 in str1:
  if "u" in str1:
    print(str1.replace("u","oo"))
  if "y" in str1:
    print(str1.replace("y","i"))
  if "e" in str1:
    print(str1.replace("e","i"))
# Out:
# murthy
# moorthy
# murthi
# moorthy
# murthi
# moorthy
# murthi
# moorthy
# murthi
# moorthy
# murthi
# moorthy
# murthi
